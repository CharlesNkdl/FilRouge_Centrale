# %% [markdown]
# # Projet Fil Rouge Centrale #
#
# Victor Bonlieu-Fortier, Charles Nikdel
#
# ---

# %% [markdown]
# ## Importation librairies ##

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import utils as ft_nous

# %%
rename_columns = [
					"index",
					"date_urg",
					"conduite",
					"m_entry",
					"m_venue",
					"age",
					"atcd_med",
					"atcd_chir",
					"cst_paspad",
					"fc_ad",
					"tmp_ad",
					"saoxy_ad",
					"fr_ad",
					"ccmu",
					"salle",
					"date_box",
					"anamn",
					"obs",
					"have_bio",
					"have_radio",
					"have_echo",
					"have_scan",
					"have_irm",
					"have_specia",
					"date_prescri_bio",
					"date_prelev_bio",
					"code_diag",
					"intitule_diag",
					"cac_admi",
					"cac_sejour",
					"date_sortie",
					"date_deb_pec_med",
					"dossier_hopit",
					"type_orient",
					"destination",
					"transfert_service",
					"transfert_hopit",
					"cp_ville",
					"ville"
					]
rename_columns
# Out:
# ['index',
#  'date_urg',
#  'conduite',
#  'm_entry',
#  'm_venue',
#  'age',
#  'atcd_med',
#  'atcd_chir',
#  'cst_paspad',
#  'fc_ad',
#  'tmp_ad',
#  'saoxy_ad',
#  'fr_ad',
#  'ccmu',
#  'salle',
#  'date_box',
#  'anamn',
#  'obs',
#  'have_bio',
#  'have_radio',
#  'have_echo',
#  'have_scan',
#  'have_irm',
#  'have_specia',
#  'date_prescri_bio',
#  'date_prelev_bio',
#  'code_diag',
#  'intitule_diag',
#  'cac_admi',
#  'cac_sejour',
#  'date_sortie',
#  'date_deb_pec_med',
#  'dossier_hopit',
#  'type_orient',
#  'destination',
#  'transfert_service',
#  'transfert_hopit',
#  'cp_ville',
#  'ville']

# %%
df = pd.read_excel("../database/db_urg.xlsx", index_col=0, header=0, names = rename_columns)
df
# Out:
#                   date_urg           conduite  \
# index
# 1      2016-06-01 00:16:00   AMBULANCE PRIVEE
# 2      2016-06-01 00:18:00   AMBULANCE PRIVEE
# 3      2016-06-01 00:36:00           POMPIERS
# 4      2016-06-01 00:43:00  MOYENS PERSONNELS
# 5      2016-06-01 01:16:00   AMBULANCE PRIVEE
# ...                    ...                ...
# 336249 2020-06-01 22:58:00   AMBULANCE PRIVEE
# 336250 2020-06-01 23:03:00   AMBULANCE PRIVEE
# 336251 2020-06-01 23:04:00   AMBULANCE PRIVEE
# 336252 2020-06-01 23:12:00  MOYENS PERSONNELS
# 336253 2020-06-01 23:54:00  MOYENS PERSONNELS
#
#                                                   m_entry  \
# index
# 1       Malaise, difficulté respi, palpitation, Pas de...
# 2       AEG, Hyperthermie et difficulté respi en maiso...
# 3                                                     NaN
# 4       1A, Hyperthermie ne cédant pas au paracetamol,...
# 5       Douleur bras gauche et mollet gauche, hémiplég...
# ...                                                   ...
# 336249  Suspicion  de pyélonéphrite,  passage au SAU  ...
# 336250     Hyperglycémie à 7gr au domicile , 0.98 en  ZAO
# 336251                     Suspicion d'infection urinaire
# 336252                                        Douleur FIG
# 336253                           Plaie derrière oreille G
#
#                                                   m_venue  age  \
# index
# 1                       Cardiologie: Palpitations Malaise   33
# 2                     Maladies infectieuses: Hyperthermie   78
# 3                                                     NaN   77
# 4                     Maladies infectieuses: Hyperthermie   38
# 5                                   Cardiologie: Phlébite   69
# ...                                                   ...  ...
# 336249        Uro-néphrologie: Suspicion de pyélonéphrite   49
# 336250        Endocrino-métabolisme: Déséquilibre diabète   64
# 336251  Uro-néphrologie: Dysurie, brulure mictionnelle...   72
# 336252  Gastro-entérologie: Douleur abdominale non épi...   16
# 336253                 Traumatologie: Plaie superficielle   63
#
#                                                  atcd_med           atcd_chir  \
# index
# 1                                                     NaN                 NaN
# 2                                                     NaN                 NaN
# 3                                                     NaN                 NaN
# 4                                                     NaN                 NaN
# 5       décembre 2007 : infarctus capsulo caudé droit ...                 NaN
# ...                                                   ...                 ...
# 336249                                                ras                 NaN
# 336250                                                NaN                 NaN
# 336251                  ESV paroxystiques   Fissure anale  Hernie de l'aine
# 336252                                                NaN                 NaN
# 336253                                                NaN                 NaN
#
#        cst_paspad fc_ad tmp_ad  ... cac_sejour   date_sortie date_deb_pec_med  \
# index                           ...
# 1          110/56    52   34.9  ...     3093.0  42522.176389     42522.043750
# 2           90/41    77   36.3  ...     3102.0  42522.461806     42522.093056
# 3          137/77    97   36.5  ...     3102.0  42522.127778              NaN
# 4          117/71   118   38.2  ...     3093.0  42522.201389     42522.081250
# 5          137/79    70   36.1  ...     3102.0  42522.663194     42522.107639
# ...           ...   ...    ...  ...        ...           ...              ...
# 336249     101/71    93     37  ...     3102.0  43984.868056     43984.075694
# 336250     149/94    82   36.3  ...     3093.0  43984.143750              NaN
# 336251    154/101    96     36  ...     3093.0  43984.130556     43984.128472
# 336252     129/75    97   37.3  ...     3093.0  43984.147917     43984.140972
# 336253        NaN   NaN    NaN  ...     3093.0  43984.095833              NaN
#
#        dossier_hopit        type_orient  \
# index
# 1                NaN    RETOUR DOMICILE
# 2                NaN  TRANSFERT EXTERNE
# 3                NaN  TRANSFERT INTERNE
# 4                NaN    RETOUR DOMICILE
# 5                NaN    RETOUR DOMICILE
# ...              ...                ...
# 336249           NaN  TRANSFERT INTERNE
# 336250           NaN    RETOUR DOMICILE
# 336251           NaN    RETOUR DOMICILE
# 336252           NaN    RETOUR DOMICILE
# 336253           NaN    RETOUR DOMICILE
#
#                                               destination  \
# index
# 1                                         RETOUR DOMICILE
# 2       Transfert CLINIQUE DUBOIS (LILLE) Motif: Conve...
# 3               Admis(e) en NEUROLOGIE B 5 EST (3281/CAC)
# 4                                         RETOUR DOMICILE
# 5                                         RETOUR DOMICILE
# ...                                                   ...
# 336249  Admis(e) en MÉDECINE POLYVALENTE POST URGENCE ...
# 336250                                    RETOUR DOMICILE
# 336251                                    RETOUR DOMICILE
# 336252                                    RETOUR DOMICILE
# 336253                                    RETOUR DOMICILE
#
#                         transfert_service  transfert_hopit cp_ville  \
# index
# 1                                     NaN              NaN    59139
# 2                                     NaN  CLINIQUE DUBOIS    59310
# 3                      NEUROLOGIE B 5 EST              NaN    59480
# 4                                     NaN              NaN    59136
# 5                                     NaN              NaN    59130
# ...                                   ...              ...      ...
# 336249  MÉDECINE POLYVALENTE POST URGENCE              NaN    59000
# 336250                                NaN              NaN    59000
# 336251                                NaN              NaN    59000
# 336252                                NaN              NaN    59370
# 336253                                NaN              NaN    59120
#
#                   ville
# index
# 1            WATTIGNIES
# 2               ORCHIES
# 3             LA BASSEE
# 4                WAVRIN
# 5            LAMBERSART
# ...                 ...
# 336249            LILLE
# 336250            LILLE
# 336251            LILLE
# 336252  MONS EN BAROEUL
# 336253             LOOS
#
# [336253 rows x 38 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 336253 entries, 1 to 336253
# Data columns (total 38 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   date_urg           336253 non-null  datetime64[ns]
#  1   conduite           334907 non-null  object
#  2   m_entry            311802 non-null  object
#  3   m_venue            307534 non-null  object
#  4   age                336253 non-null  int64
#  5   atcd_med           102623 non-null  object
#  6   atcd_chir          71134 non-null   object
#  7   cst_paspad         242618 non-null  object
#  8   fc_ad              244278 non-null  object
#  9   tmp_ad             267414 non-null  object
#  10  saoxy_ad           225761 non-null  object
#  11  fr_ad              10785 non-null   object
#  12  ccmu               293122 non-null  object
#  13  salle              336253 non-null  object
#  14  date_box           186938 non-null  float64
#  15  anamn              178028 non-null  object
#  16  obs                28559 non-null   object
#  17  have_bio           336253 non-null  object
#  18  have_radio         336253 non-null  object
#  19  have_echo          336253 non-null  object
#  20  have_scan          336253 non-null  object
#  21  have_irm           336253 non-null  object
#  22  have_specia        336253 non-null  object
#  23  date_prescri_bio   167448 non-null  float64
#  24  date_prelev_bio    164481 non-null  float64
#  25  code_diag          279595 non-null  object
#  26  intitule_diag      279595 non-null  object
#  27  cac_admi           336243 non-null  object
#  28  cac_sejour         336243 non-null  float64
#  29  date_sortie        336253 non-null  float64
#  30  date_deb_pec_med   298023 non-null  float64
#  31  dossier_hopit      6 non-null       float64
#  32  type_orient        336253 non-null  object
#  33  destination        336253 non-null  object
#  34  transfert_service  67152 non-null   object
#  35  transfert_hopit    6792 non-null    object
#  36  cp_ville           335823 non-null  object
#  37  ville              335823 non-null  object
# dtypes: datetime64[ns](1), float64(7), int64(1), object(29)
# memory usage: 100.1+ MB

# %% [markdown]
# On voit que bon, y a beaucoup de colonne mais pas mal qui contienne rien d'interessant, on va donc les supprimer
# Dans l'ordre ceux que je pense supprimer et concatenner pour certaines :
#
# - obs sert pas a grand chose et y en a pas bcq, c'est les observations des inf genre EVA ou autre
# - code diag donne le code du diagnostic, on a deja le libelle donc pas besoin
# - cac admi jsp vraiment ce que c'est ca doit etre un code de protocole, mais il faut juste récup le numéro comme le cac_sejour
# - dossier_hopit y es casi nul donc on peut tej
# - type orientation, c'est destination mais moins précis, on peut tej
# - transfert service c'est destination mais juste pour les services internes, on peut tej
# - transfert etab c'est destination mais juste pour les autres etablissements, y en as pas enorme, je pense on peut tej et et juste modif pour dire autre etab
# - le code postal et la ville jsp si c'est utile la vérité à voir, je pense qu'on peut retirer le code postal et garder la ville pour des vizu de zinzin
# - frequence respi y en as pas bcq on peut retirer
# - Je pense qu'on peut retirer aussi tout ceux qui n'ont pas un code ccmu, ca veut dire ceux qui ont pas été triagé et donc pas pris en charge par les urgences
# - salle enfaite c'est une liste de leur voyage dans les urgences, jsp si c'est utile non plus , ca clc à parser et jsp si ca sera utile
#
# Pour réduire le nbr de colonne et le contenu en info :
#
# - Conduite, on peut changer ca en 1 2 3 4 5 ... y 'en a pas bcq
# - motif entrée et admission : clean et tokenizer comme on as fait sur twitter
# - atcd med et chir idem
# - les constantes jsp pq aucune est en int il faut convert : trouver un truc pck la pression sanguine en 110 / 56 ca clc par exemple vu que c'est pas un int
# - convertir la température en int, pour remplacer les NaN juste mettre la température normale
# - la saturation en oxy, pareil remplacer les NaN par la saturation normale et convertir en int sachant que y a des inf clc qui ont met AA (air ambiant) du coup les retirer
# - anamnèse, on peut tokenizer et clean comme on as fait sur twitter
# - tout les have, à transformer en 0 1
# - les date prescri bio et prelev, peut être juste faire un delta entre les deux, y en as ils sont pas prescri donc on peut mettre 0 et d'autre qui sont prescri mais pas prelevé donc mettre la date de prescri ou la moyenne des dates de prescri jpense
# - intitule diag à tokenizer et clean
# - parser destination pour juste garder le service / hopital / autre hopital
# - ville ca a l'air d'être bon

# %%
df.columns
# Out:
# Index(['date_urg', 'conduite', 'm_entry', 'm_venue', 'age', 'atcd_med',
#        'atcd_chir', 'cst_paspad', 'fc_ad', 'tmp_ad', 'saoxy_ad', 'fr_ad',
#        'ccmu', 'salle', 'date_box', 'anamn', 'obs', 'have_bio', 'have_radio',
#        'have_echo', 'have_scan', 'have_irm', 'have_specia', 'date_prescri_bio',
#        'date_prelev_bio', 'code_diag', 'intitule_diag', 'cac_admi',
#        'cac_sejour', 'date_sortie', 'date_deb_pec_med', 'dossier_hopit',
#        'type_orient', 'destination', 'transfert_service', 'transfert_hopit',
#        'cp_ville', 'ville'],
#       dtype='object')

# %%
df = df.dropna(subset=["ccmu"])
df = df.drop(["code_diag","dossier_hopit","type_orient","transfert_service","transfert_hopit","fr_ad"],axis=1)
df.info()

# %%
df = df.drop(["obs"],axis=1)
df

# %%
df["conduite"].values[233]
# Out:
# 'AMB PUBLIQUE CHRU '

# %% [markdown]
# Maintenant je vais faire des fonctions pour traiter les données et les remettre dans le bon type en général

# %%
df = ft_nous.convertir_conduite(df, "conduite")
df["conduite"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/charles/home/FilRouge_Centrale/src/main.ipynb Cell 13 line 1
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/charles/home/FilRouge_Centrale/src/main.ipynb#X24sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> df = ft_nous.convertir_conduite(df, "conduite")
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/charles/home/FilRouge_Centrale/src/main.ipynb#X24sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> df["conduite"].value_counts()
#
# File ~/home/FilRouge_Centrale/src/utils.py:36, in convertir_conduite(df, conduite)
#      25 def convertir_conduite(df, conduite):
#      26 	df[conduite] = df[conduite].replace({"MOYENS PERSONNELS": 1,
#      27 										"AMBULANCE PRIVEE": 2,
#      28 										"POMPIERS": 3,
#    (...)
#      34 										"HELICOPTERE": 9,
#      35 										"VSL": 10})
# ---> 36 	df[conduite] = df[conduite].astype(int)
#      37 	return df
#
# File ~/home/FilRouge_Centrale/dependencies/centrale_p/lib/python3.11/site-packages/pandas/core/generic.py:6534, in NDFrame.astype(self, dtype, copy, errors)
#    6530     results = [ser.astype(dtype, copy=copy) for _, ser in self.items()]
#    6532 else:
#    6533     # else, only a single dtype is given
# -> 6534     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6535     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6536     return res.__finalize__(self, method="astype")
#
# File ~/home/FilRouge_Centrale/dependencies/centrale_p/lib/python3.11/site-packages/pandas/core/internals/managers.py:414, in BaseBlockManager.astype(self, dtype, copy, errors)
#     411 elif using_copy_on_write():
#     412     copy = False
# --> 414 return self.apply(
#     415     "astype",
#     416     dtype=dtype,
#     417     copy=copy,
#     418     errors=errors,
#     419     using_cow=using_copy_on_write(),
#     420 )
#
# File ~/home/FilRouge_Centrale/dependencies/centrale_p/lib/python3.11/site-packages/pandas/core/internals/managers.py:354, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     352         applied = b.apply(f, **kwargs)
#     353     else:
# --> 354         applied = getattr(b, f)(**kwargs)
#     355     result_blocks = extend_blocks(applied, result_blocks)
#     357 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~/home/FilRouge_Centrale/dependencies/centrale_p/lib/python3.11/site-packages/pandas/core/internals/blocks.py:616, in Block.astype(self, dtype, copy, errors, using_cow)
#     596 """
#     597 Coerce to the new dtype.
#     598
#    (...)
#     612 Block
#     613 """
#     614 values = self.values
# --> 616 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     618 new_values = maybe_coerce_values(new_values)
#     620 refs = None
#
# File ~/home/FilRouge_Centrale/dependencies/centrale_p/lib/python3.11/site-packages/pandas/core/dtypes/astype.py:238, in astype_array_safe(values, dtype, copy, errors)
#     235     dtype = dtype.numpy_dtype
#     237 try:
# --> 238     new_values = astype_array(values, dtype, copy=copy)
#     239 except (ValueError, TypeError):
#     240     # e.g. _astype_nansafe can fail on object-dtype of strings
#     241     #  trying to convert to float
#     242     if errors == "ignore":
#
# File ~/home/FilRouge_Centrale/dependencies/centrale_p/lib/python3.11/site-packages/pandas/core/dtypes/astype.py:183, in astype_array(values, dtype, copy)
#     180     values = values.astype(dtype, copy=copy)
#     182 else:
# --> 183     values = _astype_nansafe(values, dtype, copy=copy)
#     185 # in pandas we don't store numpy str dtypes, so convert to object
#     186 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~/home/FilRouge_Centrale/dependencies/centrale_p/lib/python3.11/site-packages/pandas/core/dtypes/astype.py:134, in _astype_nansafe(arr, dtype, copy, skipna)
#     130     raise ValueError(msg)
#     132 if copy or arr.dtype == object or dtype == object:
#     133     # Explicit copy, or required since NumPy can't view from / to object.
# --> 134     return arr.astype(dtype, copy=True)
#     136 return arr.astype(dtype, copy=copy)
#
# ValueError: invalid literal for int() with base 10: 'AMB PUBLIQUE CHRU '
